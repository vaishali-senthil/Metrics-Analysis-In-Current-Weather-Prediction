# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishali-senthil/Metrics-Analysis-In-Current-Weather-Prediction/blob/main/Weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import requests

# %%
api_address='http://api.openweathermap.org/data/2.5/weather?appid=b9a2ff8ccc7254763121a1019d2421e0&q='
city1,city2,city3,city4,city5,city6,city7,city8,city9,city10,city11,city12,city13,city14,city15,city16,city17,city18,city19,city20=input("City name:").split()
# Out:
# City name:Mumbai  delhi  bangalore  hyderabad  ahmedabad kanpur  surat  pune  jaipur  kolkata  thane agra  meerut shillong  bhubaneswar  salem  jammu  chandigarh vadodara  kochi

# %%
url1 = api_address+city1
url2 = api_address+city2
url3 = api_address+city3
url4 = api_address+city4
url5 = api_address+city5
url6 = api_address+city6
url7 = api_address+city7
url8 = api_address+city8
url9 = api_address+city9
url10 = api_address+city10
url11 = api_address+city11
url12 = api_address+city12
url13 = api_address+city13
url14 = api_address+city14
url15 = api_address+city15
url16 = api_address+city16
url17 = api_address+city17
url18 = api_address+city18
url19 = api_address+city19
url20 = api_address+city20

# %%
json_data1 = requests.get(url1).json()
formatted_data = json_data1['weather'][0]['description']
print(formatted_data)
json_data2 = requests.get(url2).json()
formatted_data = json_data2['weather'][0]['description']
print(formatted_data)
json_data3 = requests.get(url3).json()
formatted_data = json_data3['weather'][0]['description']
print(formatted_data)
json_data4 = requests.get(url4).json()
formatted_data = json_data4['weather'][0]['description']
print(formatted_data)
json_data5 = requests.get(url5).json()
formatted_data = json_data5['weather'][0]['description']
print(formatted_data)
json_data6 = requests.get(url6).json()
formatted_data = json_data6['weather'][0]['description']
print(formatted_data)
json_data7 = requests.get(url7).json()
formatted_data = json_data7['weather'][0]['description']
print(formatted_data)
json_data8 = requests.get(url8).json()
formatted_data = json_data8['weather'][0]['description']
print(formatted_data)
json_data9 = requests.get(url9).json()
formatted_data = json_data9['weather'][0]['description']
print(formatted_data)
json_data10 = requests.get(url10).json()
formatted_data = json_data10['weather'][0]['description']
print(formatted_data)
json_data11 = requests.get(url11).json()
formatted_data = json_data11['weather'][0]['description']
print(formatted_data)
json_data12 = requests.get(url12).json()
formatted_data = json_data12['weather'][0]['description']
print(formatted_data)
json_data13 = requests.get(url13).json()
formatted_data = json_data13['weather'][0]['description']
print(formatted_data)
json_data14 = requests.get(url14).json()
formatted_data = json_data14['weather'][0]['description']
print(formatted_data)
json_data15 = requests.get(url15).json()
formatted_data = json_data15['weather'][0]['description']
print(formatted_data)
json_data16 = requests.get(url16).json()
formatted_data = json_data16['weather'][0]['description']
print(formatted_data)
json_data17 = requests.get(url17).json()
formatted_data = json_data17['weather'][0]['description']
print(formatted_data)
json_data18 = requests.get(url18).json()
formatted_data = json_data18['weather'][0]['description']
print(formatted_data)
json_data19 = requests.get(url19).json()
formatted_data = json_data19['weather'][0]['description']
print(formatted_data)
json_data20 = requests.get(url20).json()
formatted_data = json_data20['weather'][0]['description']
print(formatted_data)
# Out:
# smoke
# smoke
# scattered clouds
# haze
# smoke
# clear sky
# haze
# broken clouds
# haze
# haze
# smoke
# clear sky
# clear sky
# clear sky
# haze
# broken clouds
# overcast clouds
# broken clouds
# smoke
# clear sky

# %%
print(json_data1)
print(json_data2)
print(json_data3)
print(json_data4)
print(json_data5)
print(json_data6)
print(json_data7)
print(json_data8)
print(json_data9)
print(json_data10)
print(json_data11)
print(json_data12)
print(json_data13)
print(json_data14)
print(json_data15)
print(json_data16)
print(json_data17)
print(json_data18)
print(json_data19)
print(json_data20)
# Out:
# {'coord': {'lon': 72.8479, 'lat': 19.0144}, 'weather': [{'id': 711, 'main': 'Smoke', 'description': 'smoke', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 302.14, 'feels_like': 302.92, 'temp_min': 301.09, 'temp_max': 302.14, 'pressure': 1012, 'humidity': 51}, 'visibility': 2500, 'wind': {'speed': 2.57, 'deg': 310}, 'clouds': {'all': 97}, 'dt': 1641213044, 'sys': {'type': 1, 'id': 9052, 'country': 'IN', 'sunrise': 1641174139, 'sunset': 1641213793}, 'timezone': 19800, 'id': 1275339, 'name': 'Mumbai', 'cod': 200}
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dataset =pd.read_csv('weather.csv')

# %%
dataset.head(20)
# Out:
#     coord__lon  coord__lat  weather__id  ...       id         name  cod
# 0      72.8479     19.0144          711  ...  1275339       Mumbai  200
# 1      77.2167     28.6667          711  ...  1273294        Delhi  200
# 2      77.6033     12.9762          802  ...  1277333    Bengaluru  200
# 3      78.4744     17.3753          721  ...  1269843    Hyderabad  200
# 4      72.6167     23.0333          711  ...  1279233    Ahmedabad  200
# 5      80.3500     26.4667          801  ...  1267995       Kanpur  200
# 6      72.8333     21.1667          721  ...  1255364        Surat  200
# 7      73.8553     18.5196          802  ...  1259229         Pune  200
# 8      75.8167     26.9167          721  ...  1269515       Jaipur  200
# 9      88.3697     22.5697          721  ...  1275004      Kolkata  200
# 10     72.9667     19.2000          711  ...  1254661        Thāne  200
# 11     78.0167     27.1833          801  ...  1279259         Agra  200
# ...

# %%
X = dataset.drop(labels=['weather__icon','base','sys__id','sys__country','main__sea_level','main__grnd_level','wind__gust','sys__type','timezone','cod'],axis=1)
Y = dataset['weather__description']

# %%
Y
# Out:
# 0                smoke
# 1                smoke
# 2     scattered clouds
# 3                 haze
# 4                smoke
# 5           few clouds
# 6                 haze
# 7     scattered clouds
# 8                 haze
# 9                 haze
# 10               smoke
# 11          few clouds
# 12           clear sky
# 13       broken clouds
# 14                haze
# 15     overcast clouds
# 16     overcast clouds
# 17    scattered clouds
# 18               smoke
# 19    scattered clouds
# Name: weather__description, dtype: object

# %%
X
# Out:
#     coord__lon  coord__lat  weather__id  ... sys__sunset       id         name
# 0      72.8479     19.0144          711  ...  1641040922  1275339       Mumbai
# 1      77.2167     28.6667          711  ...  1641038691  1273294        Delhi
# 2      77.6033     12.9762          802  ...  1641040444  1277333    Bengaluru
# 3      78.4744     17.3753          721  ...  1641039755  1269843    Hyderabad
# 4      72.6167     23.0333          711  ...  1641040507  1279233    Ahmedabad
# 5      80.3500     26.4667          801  ...  1641038226  1267995       Kanpur
# 6      72.8333     21.1667          721  ...  1641040677  1255364        Surat
# 7      73.8553     18.5196          802  ...  1641040736  1259229         Pune
# 8      75.8167     26.9167          721  ...  1641039256  1269515       Jaipur
# 9      88.3697     22.5697          721  ...  1641036781  1275004      Kolkata
# 10     72.9667     19.2000          711  ...  1641040872  1254661        Thāne
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label1 = LabelEncoder()
X['weather__main'] = label1.fit_transform(X['weather__main'])
X['weather__description'] = label1.fit_transform(X['weather__description'])
X['name'] = label1.fit_transform(X['name'])

# %%
X
# Out:
#     coord__lon  coord__lat  weather__id  ...  sys__sunset       id  name
# 0      72.8479     19.0144          711  ...   1641040922  1275339    13
# 1      77.2167     28.6667          711  ...   1641038691  1273294     5
# 2      77.6033     12.9762          802  ...   1641040444  1277333     2
# 3      78.4744     17.3753          721  ...   1641039755  1269843     6
# 4      72.6167     23.0333          711  ...   1641040507  1279233     1
# 5      80.3500     26.4667          801  ...   1641038226  1267995     9
# 6      72.8333     21.1667          721  ...   1641040677  1255364    17
# 7      73.8553     18.5196          802  ...   1641040736  1259229    14
# 8      75.8167     26.9167          721  ...   1641039256  1269515     7
# 9      88.3697     22.5697          721  ...   1641036781  1275004    11
# 10     72.9667     19.2000          711  ...   1641040872  1254661    18
# 11     78.0167     27.1833          801  ...   1641038694  1279259     0
# ...

# %%
X = pd.get_dummies(X, drop_first=True, columns=['weather__main'])
X.head()
# Out:
#    coord__lon  coord__lat  ...  weather__main_2  weather__main_3
# 0     72.8479     19.0144  ...                0                1
# 1     77.2167     28.6667  ...                0                1
# 2     77.6033     12.9762  ...                0                0
# 3     78.4744     17.3753  ...                1                0
# 4     72.6167     23.0333  ...                0                1
#
# [5 rows x 22 columns]

# %%
X
# Out:
#     coord__lon  coord__lat  ...  weather__main_2  weather__main_3
# 0      72.8479     19.0144  ...                0                1
# 1      77.2167     28.6667  ...                0                1
# 2      77.6033     12.9762  ...                0                0
# 3      78.4744     17.3753  ...                1                0
# 4      72.6167     23.0333  ...                0                1
# 5      80.3500     26.4667  ...                0                0
# 6      72.8333     21.1667  ...                1                0
# 7      73.8553     18.5196  ...                0                0
# 8      75.8167     26.9167  ...                1                0
# 9      88.3697     22.5697  ...                1                0
# 10     72.9667     19.2000  ...                0                1
# 11     78.0167     27.1833  ...                0                0
# 12     77.7000     28.9833  ...                0                0
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.25, random_state = 0)

# %%
scaler = StandardScaler()
X_train =scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
#Y_train =scaler.fit_transform(Y_train.reshape(-1, 1))
#Y_test = label1.transform(Y_test)

# %%
X_train
# Out:
# array([[-0.33668555,  1.37538658,  0.81147143,  0.89799913, -0.65014617,
#         -0.7741293 , -0.58042732, -0.74270388,  0.3731295 , -1.60989981,
#          0.87675449,  0.47430753,  0.79514121, -0.30590797,  1.64752458,
#          0.98368697, -0.36461484,  0.68434141, -0.84836996,  0.93541435,
#         -0.60302269, -0.39223227],
#        [-1.04309621, -0.23192013, -1.14088063, -0.27330408,  1.1517518 ,
#          1.26328452,  1.2554428 ,  1.01297737,  0.06644772,  0.40756957,
#         -1.1997693 , -0.67025698,  0.75511732,  0.13459951, -0.02108685,
#          0.80729681,  1.03005625, -1.64699497,  1.4816602 , -1.06904497,
#          1.6583124 , -0.39223227],
#        [ 2.35513151,  0.50762642,  0.83557455, -2.0302589 , -2.10179231,
#         -1.98413824, -2.05944212, -2.15711688,  0.29645906,  1.08005937,
#          0.87675449, -1.68663027, -1.56626808,  1.12574132,  0.00641774,
#         -1.89200724, -2.2583026 , -1.5075863 ,  1.30242712,  0.93541435,
# ...

# %%
model = Sequential()
model.add(Dense(X.shape[1],activation='relu',input_dim=X.shape[1]))
model.add(Dense(128,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 22)                506
#
#  dense_1 (Dense)             (None, 128)               2944
#
#  dense_2 (Dense)             (None, 1)                 129
#
# ...
# Total params: 3,579
# Trainable params: 3,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
X.shape[1]
# Out:
# 22

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
Y_train = label1.fit_transform(Y_train)
Y_train
# Out:
# array([5, 3, 0, 6, 5, 2, 3, 3, 5, 4, 2, 3, 6, 4, 1])

# %%
model.fit(X_train,Y_train,batch_size=10, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 1s 19ms/step - loss: 1.1926 - accuracy: 0.0667
# Epoch 2/10
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6151 - accuracy: 0.0667
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1060 - accuracy: 0.0667
# Epoch 4/10
# 2/2 [==============================] - 0s 8ms/step - loss: -0.4773 - accuracy: 0.0667
# Epoch 5/10
# 2/2 [==============================] - 0s 11ms/step - loss: -1.0122 - accuracy: 0.0667
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: -1.5940 - accuracy: 0.0667
# Epoch 7/10
# 2/2 [==============================] - 0s 16ms/step - loss: -2.0376 - accuracy: 0.0667
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: -2.6646 - accuracy: 0.0667
# Epoch 9/10
# 2/2 [==============================] - 0s 11ms/step - loss: -3.1832 - accuracy: 0.0667
# Epoch 10/10
# ...

# %%
Y_train =scaler.fit_transform(Y_train.reshape(-1, 1))
Y_test = label1.transform(Y_test)

# %%
model.evaluate(X_test, Y_test)
# Out:
# 1/1 [==============================] - 0s 384ms/step - loss: -5.6370 - accuracy: 0.0000e+00
# [-5.637046813964844, 0.0]

# %%
Y_test
# Out:
# array([6, 6, 5, 3, 6])

# %% [markdown]
# check

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
metrics = pd.read_csv('weather.csv')
plt.figure(figsize=(26,15))
plt.title('Temperature over places',fontdict={'fontweight':'bold','fontsize':30})
plt.plot(metrics.name,metrics.main__temp,label='main temp',marker='.')
plt.plot(metrics.name,metrics.main__temp_min,label='main temp min',marker='.')
plt.plot(metrics.name,metrics.main__temp_max,label='main temp max',marker='.')
plt.xticks(metrics.name)
plt.legend()
plt.show()

# %%
plt.hist(metrics.weather__main,color='y')
plt.xlabel('weather')
plt.ylabel('number of places')
plt.title('weather over places')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.hist(metrics.weather__description,color='g')
plt.xlabel('weather-description')
plt.ylabel('number of places')
plt.title('weather description')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.hist(metrics.main__temp,color='r')
plt.xlabel('weather main temperature')
plt.ylabel('number of places')
plt.title('weather')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.hist(metrics.main__temp_max,color='black')
plt.xlabel('weather main max temperature')
plt.ylabel('number of places')
plt.title('weather')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.hist(metrics.main__temp_min)
plt.xlabel('weather main min temperature')
plt.ylabel('number of places')
plt.title('weather')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
Haze=metrics.loc[metrics['weather__main']=='Haze'].count()[0]
Smoke=metrics.loc[metrics['weather__main']=='Smoke'].count()[0]
Clouds=metrics.loc[metrics['weather__main']=='Clouds'].count()[0]
Clear=metrics.loc[metrics['weather__main']=='Clear'].count()[0]

labels = ['Haze','Smoke','Clouds','Clear']
plt.pie([Haze,Smoke,Clouds,Clear], labels=labels,autopct='%.2f %%')

plt.title('weather main')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("weather1.csv")
df.plot(kind = 'scatter', x = 'name', y = 'main__temp') # scatter plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("weather1.csv")
df.plot.scatter( x = "name", y = "main__temp",c=1, cmap="viridis",xlabel="name")

# %%
df.plot(kind = 'density') # estimate density

# %%
from pandas.plotting import bootstrap_plot

data = pd.Series(np.random.rand(1000))

bootstrap_plot(data, size=10, samples=20, color="green");

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=["main__temp", "main__temp_min", "main__temp_max"])

df.plot.box();

# %%
df.plot.area(stacked=False);
